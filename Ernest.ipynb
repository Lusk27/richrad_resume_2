# %% [markdown]
# <a href="https://colab.research.google.com/github/UptoCode99/richrad_resume_2/blob/master/Ernest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import tensorflow as tf
from tensorflow.keras.layers.experimental import preprocessing

import numpy as np
import os
import time

path_to_file = tf.keras.utils.get_file('austen.txt', 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt')
# Path to file 2 is The sun Also rises by Ernest Hemingway
path_to_file2 = tf.keras.utils.get_file('sun_rises.txt','https://www.gutenberg.org/files/67138/67138-0.txt')
# Path to file 3 Art and Life by Divinci
path_to_file3 = tf.keras.utils.get_file('football.text','https://www.gutenberg.org/files/68466/68466-0.txt')
text = open(path_to_file2, 'rb').read().decode(encoding = 'utf-8')
text3 = open(path_to_file3, 'rb').read().decode(encoding= 'utf_8')
text2 = open(path_to_file, 'rb').read().decode(encoding='utf-8')
# Out:
# ...
# 425984/411290 [===============================] - 0s 0us/step

# %%
path_to_file = tf.keras.utils.get_file('austen.txt', 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt')
# Path to file 2 is The sun Also rises by Ernest Hemingway
path_to_file2 = tf.keras.utils.get_file('sun_rises.txt','https://www.gutenberg.org/files/67138/67138-0.txt')

tf.keras.utils.get_file('ernest2.test','https://www.gutenberg.org/files/61085/61085-0.txt')
tf.keras.utils.get_file('ernest3.text','https://www.gutenberg.org/files/59603/59603-0.txt')

filename = ['sun_rises.txt', 'ernest2.text', 'ernest3.text']

#with open('file3.txt', 'w') as outfile:
#  for names in filename:
#    with open(names) as infile:
#      outfile.write(infile.read())
#    outfile.write("\n")
# Out:
# ...
# 90112/78041 [==================================] - 0s 0us/step

# %%
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 511Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 4.95Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 240Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:19, 25.4Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 384Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 5.64Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.67Mit/s]

# %%
import tensorflow as tf
tf.compat.v1.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              dataset=path_to_file2,
              model_name='124M',
              steps=1000,
              restore_from='latest',
              run_name='run2',
              print_every=10,

              )
# Out:
# Loading checkpoint models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# dataset has 122157 tokens
# Training...
# [10 | 28.70] loss=2.43 avg=2.43
# [20 | 50.54] loss=2.53 avg=2.48
# [30 | 72.83] loss=2.29 avg=2.42
# [40 | 95.55] loss=2.26 avg=2.38
# [50 | 118.16] loss=2.23 avg=2.35
# [60 | 140.61] loss=2.17 avg=2.32
# [70 | 163.06] loss=2.14 avg=2.29
# [80 | 185.64] loss=2.01 avg=2.26
# [90 | 208.22] loss=1.99 avg=2.22
# [100 | 230.76] loss=1.81 avg=2.18
# ======== SAMPLE 1 ========
#  understood, it was all true, and he smiled at me.
# “Well,” he said with a smile, “what would have happened if he’d known it all?”
#
# “He couldn’t have said it.”
#
# “He could have,” I said. The count took a long drink; it gave me a pang.
#
# “Well,” I said, “it could be that’d be good.”
#
# “He can’t say it!”
#
# I saw he was having a wonderful time.
#
# “Aren’t you embarrassed that you had to look after Edna?”
#
# He laughed.
#
# ...

# %%
gpt2.generate(sess,
              model_name="124M",
              prefix="The world seemed like such a peaceful place until the magic tree was discovered in London",
              length=500,
              temperature=0.3,
              top_p=0.5,
              nsamples=2,
              batch_size=2
              )
# Out:
# The world seemed like such a peaceful place until the magic tree was discovered in London. It was like a certain pestilentiality to all the little things. You know, the sort I was with when he was with her.
#
# “He’s a good chap.”
#
# “He’s written a wonderful romance.”
#
# “I wanted to ask you one time. If you wouldn’t mind,” Harvey put in. “Tell me about it.”
#
# “I’ll be in Paris.”
#
# “Yes,” I said, “I’d be at the office. I’m most looking forward to the
# afternoon.”
#
# Harvey looked around at the café. The waiters were sitting on the edge of the
# montre. He asked a waiter to get a table, and when he got no ticket he
# handed the waiter a franc and the waiter got his turn to get a drink. The waiter
# was very pleased. The waiter was going to start the next day. The next day he
# was getting his money’s allowance.
#
# “I’ve got two more tickets to Paris,” I said. “I’ll get them for you.”
#
# “No,” he said, and handed back the amount he had.
#
# ...
